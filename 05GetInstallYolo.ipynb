# %%
import os
# ! git clone https://github.com/ultralytics/yolov5

# %%
os.chdir(r"yolov5")
! pip install -r requirements.txt
# Out:
# ...
#   Using cached GitPython-3.1.30-py3-none-any.whl (184 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 1.8 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#   Using cached opencv_python-4.7.0.68-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (61.8 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.2/280.2 kB 7.1 MB/s eta 0:00:008.6 MB/s eta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.5/34.5 MB 1.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#   Using cached thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 7.2 MB/s eta 0:00:00
# ...
#   Using cached tensorboard-2.11.2-py3-none-any.whl (6.0 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 1.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.3/293.3 kB 5.5 MB/s eta 0:00:00 MB/s eta 0:00:01
# ...
#   Using cached gitdb-4.0.10-py3-none-any.whl (62 kB)
# ...
